# %%
import csv
import pandas as pd
import random
import numpy as np


# read the Input Files and append them together in the merged file 

tf = open('merge_citibike_data.csv', 'a')
tf.write(open("JC-201701-citibike-tripdata.csv").read())
tf.write(open("JC-201702-citibike-tripdata.csv").read())
tf.write(open("JC-201703-citibike-tripdata.csv").read())
tf.write(open("JC-201704-citibike-tripdata.csv").read())
tf.write(open("JC-201705-citibike-tripdata.csv").read())
tf.write(open("JC-201706-citibike-tripdata.csv").read())
tf.write(open("JC-201707-citibike-tripdata.csv").read())
tf.write(open("JC-201708-citibike-tripdata.csv").read())
tf.write(open("JC-201709-citibike-tripdata.csv").read())
tf.write(open("JC-201710-citibike-tripdata.csv").read())
tf.write(open("JC-201711-citibike-tripdata.csv").read())
tf.write(open("JC-201712-citibike-tripdata.csv").read())
tf.close()

# %%
mergedcitibike_data = pd.read_csv("merge_citibike_data.csv")
mergedcitibike_data.count()
# Out:
# Trip Duration              1002201
# Start Time                 1002201
# Stop Time                  1002201
# Start Station ID           1002201
# Start Station Name         1002201
# Start Station Latitude     1002201
# Start Station Longitude    1002201
# End Station ID             1002201
# End Station Name           1002201
# End Station Latitude       1002201
# End Station Longitude      1002201
# Bike ID                    1002201
# User Type                  1001667
# Birth Year                  930320
# Gender                     1002201
# dtype: int64

# %%
citibike_df = pd.read_csv('merge_citibike_data.csv')

# %%
citibike_df.isnull().sum()
# Out:
# Trip Duration                  0
# Start Time                     0
# Stop Time                      0
# Start Station ID               0
# Start Station Name             0
# Start Station Latitude         0
# Start Station Longitude        0
# End Station ID                 0
# End Station Name               0
# End Station Latitude           0
# End Station Longitude          0
# Bike ID                        0
# User Type                    534
# Birth Year                 71881
# Gender                         0
# dtype: int64

# %%
citibike_df.dropna()
# Out:
#         Trip Duration           Start Time            Stop Time  \
# 0                1076  2017-03-01 00:03:02  2017-03-01 00:20:58
# 1                 978  2017-03-01 00:09:02  2017-03-01 00:25:20
# 2                1789  2017-03-01 00:28:11  2017-03-01 00:58:00
# 3                 613  2017-03-01 00:52:30  2017-03-01 01:02:44
# 4                2418  2017-03-01 00:54:40  2017-03-01 01:34:59
# 5                1141  2017-03-01 01:02:28  2017-03-01 01:21:29
# 6                 805  2017-03-01 03:08:07  2017-03-01 03:21:33
# 7                 114  2017-03-01 03:35:44  2017-03-01 03:37:39
# 8                 164  2017-03-01 03:38:03  2017-03-01 03:40:47
# 9                 181  2017-03-01 04:43:05  2017-03-01 04:46:07
# 10                152  2017-03-01 04:43:55  2017-03-01 04:46:28
# 11                206  2017-03-01 04:44:54  2017-03-01 04:48:21
# 12                473  2017-03-01 05:12:55  2017-03-01 05:20:48
# 13                235  2017-03-01 05:16:16  2017-03-01 05:20:12
# ...

# %%
citibike_df=citibike_df.dropna(axis=1,how='any')

# %%
citibike_df.isnull().sum()
# Out:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# Gender                     0
# dtype: int64

# %%
citibike_df.count()
# Out:
# Trip Duration              1002201
# Start Time                 1002201
# Stop Time                  1002201
# Start Station ID           1002201
# Start Station Name         1002201
# Start Station Latitude     1002201
# Start Station Longitude    1002201
# End Station ID             1002201
# End Station Name           1002201
# End Station Latitude       1002201
# End Station Longitude      1002201
# Bike ID                    1002201
# Gender                     1002201
# dtype: int64

# %%
citibike_df.to_csv("cleaned_2017_citibikedata.csv")
